# %%
import torch
import torch.nn as nn
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D  
from rbf_layer import RBFLayer, l_norm, rbf_gaussian
import traintest as tt
import models
import torch.utils.data as data_utils
import torch.nn.functional as F
import torch.optim as optim
from sklearn import mixture, preprocessing, datasets
from copy import deepcopy

# %%
# Generate dataset
data, labels = datasets.make_moons(n_samples=1000, shuffle=True, noise=.15)

df = pd.DataFrame(data, columns=['feature_1', 'feature_2'])
df=(df-df.min())/(df.max()-df.min()) # normalize [0,1]
df['labels'] = labels
data = torch.tensor(df[['feature_1', 'feature_2']].to_numpy(), dtype=torch.float) 
device=torch.device('cuda:0')

# %%
df.head()
# Out:
#    feature_1  feature_2  labels
# 0   0.430301   0.304174       1
# 1   0.542416   0.913893       0
# 2   0.398269   0.491326       1
# 3   0.510990   0.290784       1
# 4   0.255858   0.862730       0

# %%
sns.scatterplot(x = df.feature_1, y = df.feature_2, hue = df.labels)
# Out:
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
gmm = models.GMM(25 ,2)
gmm.find_solution(data,iterate=True)
# Out:
# C:\Users\samle\.conda\envs\CCU\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\samle\.conda\envs\CCU\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
x = y = np.arange(-.03, 1.03, 0.01)

# %%
points = []
for xx in x:
    for yy in y:
        points.append([xx, yy])

# %%
z = torch.logsumexp(gmm(torch.tensor(points)), dim=0).detach().view(len(x), len(y)).T

# %%
df2 = pd.DataFrame(gmm.mu.detach(), columns=['feature_1', 'feature_2'])
df2['labels'] = ['gmm_center']*25

# %%
sns.set_theme()
plt.contourf(x,y,z)
sns.scatterplot(data = pd.concat([df, df2], axis=0), x = 'feature_1', y = 'feature_2', hue = 'labels')
# Out:
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %% [markdown]
# ### MLP Classifier

# %%
label = torch.tensor(labels, dtype=torch.int64)


train = data_utils.TensorDataset(data, label)
train_loader = data_utils.DataLoader(train, batch_size=250, shuffle=True)

# %%
train_loader

# %%
class TwoMoonsNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 32)
        self.fc2 = nn.Linear(32, 64)
        self.fc3 = nn.Linear(64, 2)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

lr = 0.1
lr_gmm = 1e-3
decay = 5e-4

net = TwoMoonsNet()
param_groups = [{'params':net.parameters(),'lr':lr, 'weight_decay':decay}]
loss = []
acc = []
optimizer = optim.Adam(param_groups)

for epoch in range(200):
    
    l,a,_= tt.train_plain(net.to(device), device, train_loader, optimizer, 
                epoch, verbose=-1)
    loss.append(l)
    acc.append(a)

# %%
sns.lineplot(acc)
plt.title('Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
output = net(torch.tensor(points, dtype=torch.float32, device=device)).detach()

# %%
output.max(1)[0].exp()
# Out:
# tensor([0.7461, 0.7809, 0.8122,  ..., 0.9298, 0.9149, 0.8972], device='cuda:0')

# %%
data
# Out:
# tensor([[0.4303, 0.3042],
#         [0.5424, 0.9139],
#         [0.3983, 0.4913],
#         ...,
#         [0.5537, 0.6574],
#         [0.6471, 0.2618],
#         [0.6937, 0.3184]])

# %%
# helper functions
def plot_conf(net,
              data=data,
              labels=label,
              device=device,
              points=points,
              dim=len(x)):
    output = net(torch.tensor(points, dtype=torch.float32, device=device)).detach()
    output_data = net(data.to(device)).detach().cpu()
    pred = output.max(1)[0].exp()
    z = pred.view(dim, dim).detach().t().cpu().numpy()
    # COLORS FOR CLASSES IN CLASS VS OOD
    p, yhat = output_data.max(1)
    p = p.exp()
    acc = (yhat.eq(labels)).sum()/len(labels)
 
    
    plt.contourf(x, y, z, vmin=.5, vmax=1, extend='both',cmap='bone',zorder=0)
    plt.colorbar()#ticks=np.linspace(.5,1.,6))
    sns.scatterplot(x = data[:,0], y = data[:,1], hue = yhat)
    plt.title(f'Accuracy:{acc:.3f}')

# %%
plot_conf(net)

# %% [markdown]
# ### CCU Robust Model Learning

# %%
gmm = models.GMM(25 ,2)
gmm.find_solution(data,iterate=True)
# Out:
# C:\Users\samle\.conda\envs\CCU\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\samle\.conda\envs\CCU\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
gmm.mu.requires_grad_(False) # turn of learning of centers
# Out:
# Parameter containing:
# tensor([[0.7452, 0.1704],
#         [0.2024, 0.8007],
#         [0.9159, 0.6163],
#         [0.3901, 0.3927],
#         [0.5673, 0.6923],
#         [0.0902, 0.5538],
#         [0.7653, 0.3485],
#         [0.6236, 0.6190],
#         [0.3834, 0.5026],
#         [0.8654, 0.3660],
#         [0.4459, 0.2304],
#         [0.1387, 0.6729],
#         [0.3991, 0.8764],
#         [0.4731, 0.7840],
#         [0.8952, 0.4848],
#         [0.6284, 0.4759],
#         [0.7059, 0.2599],
#         [0.8172, 0.2539],
#         [0.2652, 0.8982],
#         [0.0635, 0.4242],
#         [0.4635, 0.3147],
#         [0.5894, 0.2016],
#         [0.5452, 0.8069],
#         [0.3104, 0.7961],
#         [0.3492, 0.6340]])

# %%
data_out = torch.rand(1000, 2, dtype=torch.float)
label_out = torch.zeros(1000, dtype=torch.int64)


train_out = data_utils.TensorDataset(data_out, label_out)
train_loader_out = data_utils.DataLoader(train_out, batch_size=250, shuffle=True)

# %%
CCU = models.RobustModel(deepcopy(net), deepcopy(gmm), 0.0, dim=2)
lr_gmm = 1e-4
param_groups = [{'params':CCU.base_model.parameters(),'lr':lr, 'weight_decay':decay},
               {'params':CCU.mm.parameters(),'lr':lr_gmm, 'weight_decay':0.},
               ] 
loss = []
acc = []
optimizer = optim.Adam(param_groups)

# %%
plot_conf(CCU.to(device))

# %%
for epoch in range(1000):
    l,a,_= tt.train_CEDA_gmm(CCU.to(device), device, train_loader, optimizer, 
                epoch, verbose=-1, noise_loader=train_loader_out)

# %%
plot_conf(CCU.to(device))

# %%
for epoch in range(250):
    l,a,_= tt.train_CEDA_gmm(CCU.to(device), device, train_loader, optimizer, 
                epoch, verbose=-1, noise_loader=train_loader_out)

# %%
plot_conf(CCU)

# %%
centers = CCU.mm.mu.detach().cpu()

# %%
sns.scatterplot(x = df.feature_1, y = df.feature_2, hue = df.labels)
# Out:
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
sns.scatterplot(x=centers[:,0], y=centers[:,1], hue=[3]*len(centers))
sns.scatterplot(x = df.feature_1, y = df.feature_2, hue = df.labels)
# Out:
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
output = CCU(torch.tensor(points, dtype=torch.float32, device=device)).detach()

# %%
pred = output.max(1)[0].exp()

# %%
pred.max()
# Out:
# tensor(0.7718, device='cuda:0')

# %%
output.max(1)[0].max().exp()
# Out:
# tensor(0.7718, device='cuda:0')

# %%
gmm_out = models.GMM(10 ,2)
gmm
gmm_out.find_solution(data_out,iterate=True)

# %%
# Define an RBF layer where the dimensionality of the input feature is 2,
# the number of kernels is 3, and 2 output features

# euclidean norm
def euclidean_norm(x):
    return torch.norm(x, p=2, dim=-1)


# Gaussian RBF
def rbf_gaussian(x):
    return (-x.pow(2)).exp()


class TwoMoonsNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.rbf = RBFLayer(in_features_dim=2,
                               num_kernels=6,
                               out_features_dim=6,
                               radial_function=rbf_gaussian,
                               norm_function=euclidean_norm,
                               normalization=True)
        self.fc1 = nn.Linear(6, 2)
        
    def forward(self, x):
        x = F.relu(self.rbf(x))
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)
device=torch.device('cuda:0')

# %%
data.min()
# Out:
# tensor(0.)

# %%
data.max()
# Out:
# tensor(1.)

# %%
def fun(x, y, center, shape):
    diff = center.T - [x, y]
    r = np.linalg.norm(diff, axis=0)
    return np.exp(-(shape * r) ** 2)

# %%
lr = 0.1
lr_gmm = 1e-3
decay = 5e-4

net = TwoMoonsNet()
param_groups = [{'params':net.parameters(),'lr':lr, 'weight_decay':decay}]

optimizer = optim.Adam(param_groups)

for epoch in range(100):
     tt.train_plain(net.to(device), device, train_loader, optimizer, 
                    epoch, verbose=10, noise_loader=iter(train_loader_out),
                   )
# Out:
# Train Epoch: 0 [506/1000 (51%)]	Loss: 1.396240
# Train Epoch: 1 [500/1000 (50%)]	Loss: 1.357685
# Train Epoch: 2 [744/1000 (74%)]	Loss: 1.103911
# Train Epoch: 3 [868/1000 (87%)]	Loss: 0.689275
# Train Epoch: 4 [868/1000 (87%)]	Loss: 0.608232
# Train Epoch: 5 [867/1000 (87%)]	Loss: 0.544783
# Train Epoch: 6 [875/1000 (88%)]	Loss: 0.537684
# Train Epoch: 7 [873/1000 (87%)]	Loss: 0.547715
# Train Epoch: 8 [879/1000 (88%)]	Loss: 0.519470
# Train Epoch: 9 [886/1000 (89%)]	Loss: 0.509415
# Train Epoch: 10 [885/1000 (88%)]	Loss: 0.505061
# Train Epoch: 11 [881/1000 (88%)]	Loss: 0.499333
# Train Epoch: 12 [878/1000 (88%)]	Loss: 0.497625
# Train Epoch: 13 [890/1000 (89%)]	Loss: 0.487781
# Train Epoch: 14 [889/1000 (89%)]	Loss: 0.464891
# Train Epoch: 15 [891/1000 (89%)]	Loss: 0.449480
# Train Epoch: 16 [903/1000 (90%)]	Loss: 0.447024
# Train Epoch: 17 [903/1000 (90%)]	Loss: 0.458846
# Train Epoch: 18 [890/1000 (89%)]	Loss: 0.491762
# Train Epoch: 19 [887/1000 (89%)]	Loss: 0.472358
# Train Epoch: 20 [908/1000 (91%)]	Loss: 0.472932
# Train Epoch: 21 [905/1000 (90%)]	Loss: 0.469403
# Train Epoch: 22 [900/1000 (90%)]	Loss: 0.437727
# Train Epoch: 23 [913/1000 (91%)]	Loss: 0.460459
# Train Epoch: 24 [897/1000 (90%)]	Loss: 0.448543
# Train Epoch: 25 [914/1000 (91%)]	Loss: 0.426464
# Train Epoch: 26 [910/1000 (91%)]	Loss: 0.403860
# Train Epoch: 27 [913/1000 (91%)]	Loss: 0.428865
# Train Epoch: 28 [919/1000 (92%)]	Loss: 0.391732
# Train Epoch: 29 [913/1000 (91%)]	Loss: 0.394314
# Train Epoch: 30 [923/1000 (92%)]	Loss: 0.388546
# Train Epoch: 31 [926/1000 (93%)]	Loss: 0.379997
# Train Epoch: 32 [921/1000 (92%)]	Loss: 0.378603
# Train Epoch: 33 [915/1000 (92%)]	Loss: 0.378649
# Train Epoch: 34 [920/1000 (92%)]	Loss: 0.391495
# Train Epoch: 35 [918/1000 (92%)]	Loss: 0.391584
# Train Epoch: 36 [922/1000 (92%)]	Loss: 0.401710
# Train Epoch: 37 [925/1000 (92%)]	Loss: 0.381381
# Train Epoch: 38 [925/1000 (92%)]	Loss: 0.379456
# Train Epoch: 39 [923/1000 (92%)]	Loss: 0.364787
# Train Epoch: 40 [935/1000 (94%)]	Loss: 0.334661
# Train Epoch: 41 [935/1000 (94%)]	Loss: 0.331553
# Train Epoch: 42 [947/1000 (95%)]	Loss: 0.293869
# Train Epoch: 43 [947/1000 (95%)]	Loss: 0.270424
# Train Epoch: 44 [967/1000 (97%)]	Loss: 0.218255
# Train Epoch: 45 [976/1000 (98%)]	Loss: 0.173552
# Train Epoch: 46 [948/1000 (95%)]	Loss: 0.253616
# Train Epoch: 47 [917/1000 (92%)]	Loss: 0.454926
# Train Epoch: 48 [931/1000 (93%)]	Loss: 0.332786
# Train Epoch: 49 [946/1000 (95%)]	Loss: 0.244505
# Train Epoch: 50 [960/1000 (96%)]	Loss: 0.218666
# Train Epoch: 51 [974/1000 (97%)]	Loss: 0.185737
# Train Epoch: 52 [981/1000 (98%)]	Loss: 0.128595
# Train Epoch: 53 [973/1000 (97%)]	Loss: 0.171495
# Train Epoch: 54 [985/1000 (98%)]	Loss: 0.132163
# Train Epoch: 55 [986/1000 (99%)]	Loss: 0.111600
# Train Epoch: 56 [982/1000 (98%)]	Loss: 0.109696
# Train Epoch: 57 [987/1000 (99%)]	Loss: 0.096220
# Train Epoch: 58 [988/1000 (99%)]	Loss: 0.089354
# Train Epoch: 59 [985/1000 (98%)]	Loss: 0.091863
# Train Epoch: 60 [990/1000 (99%)]	Loss: 0.085348
# Train Epoch: 61 [986/1000 (99%)]	Loss: 0.087657
# Train Epoch: 62 [988/1000 (99%)]	Loss: 0.094415
# Train Epoch: 63 [982/1000 (98%)]	Loss: 0.106707
# Train Epoch: 64 [983/1000 (98%)]	Loss: 0.099696
# Train Epoch: 65 [979/1000 (98%)]	Loss: 0.125516
# Train Epoch: 66 [978/1000 (98%)]	Loss: 0.133920
# Train Epoch: 67 [973/1000 (97%)]	Loss: 0.158141
# Train Epoch: 68 [978/1000 (98%)]	Loss: 0.123608
# Train Epoch: 69 [983/1000 (98%)]	Loss: 0.106476
# Train Epoch: 70 [988/1000 (99%)]	Loss: 0.098629
# Train Epoch: 71 [984/1000 (98%)]	Loss: 0.100165
# Train Epoch: 72 [986/1000 (99%)]	Loss: 0.092069
# Train Epoch: 73 [987/1000 (99%)]	Loss: 0.093251
# Train Epoch: 74 [989/1000 (99%)]	Loss: 0.088118
# Train Epoch: 75 [981/1000 (98%)]	Loss: 0.097891
# Train Epoch: 76 [979/1000 (98%)]	Loss: 0.142423
# Train Epoch: 77 [971/1000 (97%)]	Loss: 0.160852
# Train Epoch: 78 [968/1000 (97%)]	Loss: 0.163699
# Train Epoch: 79 [972/1000 (97%)]	Loss: 0.140013
# Train Epoch: 80 [976/1000 (98%)]	Loss: 0.154503
# Train Epoch: 81 [972/1000 (97%)]	Loss: 0.144480
# Train Epoch: 82 [982/1000 (98%)]	Loss: 0.120917
# Train Epoch: 83 [983/1000 (98%)]	Loss: 0.110277
# Train Epoch: 84 [987/1000 (99%)]	Loss: 0.106247
# Train Epoch: 85 [985/1000 (98%)]	Loss: 0.095269
# Train Epoch: 86 [985/1000 (98%)]	Loss: 0.093893
# Train Epoch: 87 [989/1000 (99%)]	Loss: 0.085093
# Train Epoch: 88 [986/1000 (99%)]	Loss: 0.084334
# Train Epoch: 89 [985/1000 (98%)]	Loss: 0.085715
# Train Epoch: 90 [987/1000 (99%)]	Loss: 0.082152
# Train Epoch: 91 [982/1000 (98%)]	Loss: 0.100925
# Train Epoch: 92 [985/1000 (98%)]	Loss: 0.104462
# Train Epoch: 93 [986/1000 (99%)]	Loss: 0.090620
# Train Epoch: 94 [984/1000 (98%)]	Loss: 0.105033
# Train Epoch: 95 [986/1000 (99%)]	Loss: 0.101612
# Train Epoch: 96 [983/1000 (98%)]	Loss: 0.092563
# Train Epoch: 97 [984/1000 (98%)]	Loss: 0.115246
# Train Epoch: 98 [986/1000 (99%)]	Loss: 0.090312
# Train Epoch: 99 [985/1000 (98%)]	Loss: 0.096512

# %%
kernels = net.rbf.get_kernels_centers.cpu().numpy()
shapes = net.rbf.get_shapes.cpu().numpy()

# %%
kernels
# Out:
# array([[-0.5927859 , -0.16338791],
#        [-0.6547231 ,  0.5421887 ],
#        [ 0.6423027 ,  1.0496914 ],
#        [-0.28533864,  0.5935448 ],
#        [ 1.1115012 , -0.257926  ],
#        [ 0.64188933,  0.46405897]], dtype=float32)

# %%
shapes
# Out:
# array([2.238056 , 3.1768358, 4.330525 , 3.5203943, 1.4822142, 7.9874506],
#       dtype=float32)

# %%
x = y = np.arange(0,1, 0.05)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots()
for i in range(6):
    center = kernels[i][:, None].repeat(400, axis=1).T
    zs = np.array(fun(X.ravel(), Y.ravel(), center, shapes[i].repeat(400)))
    Z = zs.reshape(X.shape)

    CS = ax.contour(X, Y, Z)
    ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Learnt kernels')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.grid()
sns.scatterplot(x = df.feature_1, y = df.feature_2, hue = df.labels)
plt.show()

# %%
class RbfNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.rbf = RBFLayer(in_features_dim=2,
                               num_kernels=6,
                               out_features_dim=6,
                               radial_function=rbf_gaussian,
                               norm_function=euclidean_norm,
                               normalization=True)
        self.fc1 = nn.Linear(6, 2)
        
    def forward(self, x):
        x = F.relu(self.rbf(x))
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)

DA = models.RobustModel(

# %%
sns.scatterplot(x = df.feature_1, y = df.feature_2, hue = df.labels)

# %% [markdown]
# ## Plot kernels

# %%
kernels = rbf.get_kernels_centers.numpy()
shapes = rbf.get_shapes.numpy()

def fun(x, y, center, shape):
    diff = center.T - [x, y]
    r = np.linalg.norm(diff, axis=0)
    return np.exp(-(shape * r) ** 2)

x = y = np.arange(-2.5, 2.5, 0.05)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots()

for i in range(3):
    center = kernels[i][:, None].repeat(10000, axis=1).T
    zs = np.array(fun(X.ravel(), Y.ravel(), center, shapes[i].repeat(10000)))
    Z = zs.reshape(X.shape)

    CS = ax.contour(X, Y, Z)
    ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Learnt kernels')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.grid()
plt.show()

# %%
x = y = np.arange(-2.5, 2.5, 0.05)
X, Y = np.meshgrid(x, y)

# Compute model prediction
inp = torch.tensor([X.ravel(), Y.ravel()]).T
Z = rbf(inp).argmax(dim=1).detach().numpy()

# Put the result into a color plot
Z = Z.reshape(X.shape)
plt.contourf(X, Y, Z, cmap=cm.Pastel1)

# Plot dataset
plt.scatter(X0[:, 0], X0[:, 1], c='r')
plt.scatter(X1[:, 0], X1[:, 1], c='m')
plt.scatter(X2[:, 0], X2[:, 1], c='gray')

plt.title('Decision boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.plot()
plt.savefig('example_classification_img.png', bbox_inches='tight')
